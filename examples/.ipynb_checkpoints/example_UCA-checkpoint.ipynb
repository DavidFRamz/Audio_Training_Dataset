# %% [markdown]
# # &#9989; Import modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from scipy.io import wavfile
import IPython
import dataSetAudio as dsa

# %% [markdown]
# ## &#128221;&#127911; Set some parameters and get the audio file

# %%
#number of chanels/mics in the array
M = 8
# voice data and sampling frequency
fs, data = wavfile.read('../AMI/amicorpus/ES2004a/audio/ES2004a.Array2-02.wav')

# %% [markdown]
# ## &#128640; Create audio training dataset

# %%
# Create object:
dset = dsa.dataSetAudio()
#Create dataset
data_segs = (1,2) # once the VAD is done, i take from seg 1 to 2
intv_lenghts = 150
dset.SimuData("datasetUCA.csv",data,fs,M,array_mic='UCA',length=data_segs,random=intv_lenghts)

# %% [markdown]
# ## &#127912; Plotting the training dataset

# %%
f = open("datasetUCA.csv","r")
dists = []
doas = []
for line in iter(lambda: f.readline(), ''):
    separar = line.split(',')
    doas.append(float(separar[0]))
    dists.append(float(separar[1]))
f.close()
doas = (np.asarray(doas))/180*np.pi
locs = []
for i,j in zip(doas, dists):
    locs.append((j*np.cos(i),j*np.sin(i)))
locs=np.array(locs)+5
fig = plt.figure()
plt.plot(5,5,'rs',locs[:,0],locs[:,1],'b.')
plt.axis([0,10,0,10])
plt.ylabel("Largo [m]")
plt.xlabel("Ancho [m]")
plt.grid(True)
